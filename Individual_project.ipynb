# %% [markdown]
# # Exploring Crime Data with Python

# %% [markdown]
# | **Assignment Details**        | **2024-25 Academic Year**     |
# | ------------------------------ | ----------------------------- |
# | **Academic Level**            | Level 7 (Postgraduate)       |
# | **Programme**                 | MSc Business Analytics       |
# | **Module Code**               | MN5813                       |
# | **Module Leader**             | Alex Reppel                  |
# | **Assignment Type**           | Individual Assignment (No. 2)|
# | **Assignment Title**          | Exploring Crime Data with Python |

# %% [markdown]
# | Candidate number                  |
# | ------------------------------------ |
# |  2508232 |

# %% [markdown]
# ---
# # Introduction
# In today’s data-driven era, addressing societal challenges like crime requires advanced analytical tools. Exploratory Data Analysis (EDA) provides a structured approach to uncover patterns and trends in crime data, offering valuable insights for decision-making in law enforcement and public policy (Pearson, 2018). This report examines crime data from Los Angeles (2020–present) to explore spatial and temporal trends, correlations with economic factors, and other determinants of criminal activity.
#
# Crime is influenced by a myriad of socioeconomic, demographic, and environmental factors, such as unemployment, poverty, and urbanization (Raphael & Winter-Ebmer, 2001). By integrating these factors into the analysis, this project aims to provide actionable insights that support evidence-based strategies for improving public safety and community well-being.
#
# The overarching goal is to employ Python-based techniques for cleaning, analyzing, and visualizing crime data to identify key trends and develop predictive models. The insights generated can inform policies that reduce crime and enhance societal resilience.
#
# ---
#
# # Aim and Objectives
#
# ## Aim
# To leverage Python-based exploratory data analysis (EDA) techniques to uncover patterns, trends, and factors influencing crime rates from 2020 to the present, thereby aiding evidence-based decision-making in law enforcement and community safety strategies.
#
# ## Objectives
# 1. To clean and preprocess crime data for effective analysis, ensuring accuracy and consistency in datasets.
# 2. To analyze spatial and temporal trends in crime rates, identifying high-risk periods and regions.
# 3. To explore correlations between economic factors and crime rates, drawing actionable insights for policy formulation.
#
# ---
#
# # Literature Review
# Exploratory Data Analysis (EDA) serves as a foundation for extracting meaningful insights from datasets. Pearson (2018) highlights that EDA enables the identification of patterns and trends, laying the groundwork for informed decision-making. In the context of crime, EDA can reveal significant insights into the social and economic factors driving criminal activity (Setiawan, 2020). Studies like Raphael and Winter-Ebmer (2001) have also established a relationship between unemployment and crime, emphasizing the need to integrate economic variables in crime analysis.
#
# For this project, crime data from Los Angeles between 2020 and the present will be analyzed alongside economic indicators like GDP and unemployment rates. Similar to approaches in studies like "Measuring the performance of nations at the Summer Olympics using data envelopment analysis," this integration aims to assess the interplay of socioeconomic variables with crime metrics. By employing Python libraries such as pandas, matplotlib, and seaborn, this project not only visualizes data trends but also generates actionable insights to enhance public safety measures.

# %% [markdown]
# ---
# # Data Acquisition:
# In the data acquisition phase, Python and its powerful data manipulation library,
# pandas, were used to access and load the dataset for analysis. The dataset, titled
# Crime_Data_from_2020_to_Present.csv, was sourced from the provided link [Crime
# Data from 2020 to Present]. This CSV file contains detailed crime data ranging from
# the year 2020 to the present.
#
# By utilizing the pandas library, the dataset was imported and structured for easy
# manipulation and further analysis. Specifically, the pd.read_csv() function was used
# to read the CSV file, which created a DataFrame — a versatile tabular data structure
# commonly used in data analysis.
#
# The resulting DataFrame, named crime_data, forms the basis for the exploratory data
# analysis (EDA). Through this structured data, trends, patterns, and insights will be
# uncovered to better understand the nature of crime during this period.
#
# ---

# %% [markdown]
# # Project Setup Instructions
#
# ## Steps to Run the Notebook
#
# ### 1. Download the Notebook
# Access the notebook from the GitHub repository:
# **[Individual Project Repository](https://github.com/Siddhantb23/Individual_project)**
# Download the file `individual_project.ipynb`.
#
# ---
#
# ### 2. Download Datasets
# #### Dataset 1: Crime Data (2020 to Present)
# - **Direct Download**: [Crime_Data_from_2020_to_Present.csv](https://data.lacity.org/api/views/2nrs-mtv8/rows.csv?accessType=DOWNLOAD)
# - **Alternate Link**: [Crime Data on Data.gov](https://catalog.data.gov/dataset/crime-data-from-2020-to-present)
#
# #### Dataset 2: Los Angeles Economic Data
# - **Download Link**: [Economic Data for Los Angeles (Kaggle)](https://www.kaggle.com/datasets/harshbora94/economic-data-for-los-angeles)
#
# ---
#
# ### 3. Organize Files
# Place the following in one folder:
# - `individual_project.ipynb`
# - `Crime_Data_from_2020_to_Present.csv`
# - `la_economicdata.csv`
#
# ---
#
# ### 4. Run the Notebook
# Open `individual_project.ipynb` in Jupyter Notebook, Google Colab, or any Python IDE with Jupyter support. Ensure required libraries (e.g., pandas, matplotlib, seaborn) are installed.
#
# ---
#
# ### 5. Output
# Running the notebook will generate five visualizations as PNG files, saved in the same folder.
#
#
# ---

# %%
#Data Acquisition: Download the dataset from the provided link and load i
#Importing required libraries for the Project
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
# %matplotlib inline
#loading the dataset
df=pd.read_csv('Crime_Data_from_2020_to_Present.csv')

# %% [markdown]
# ---
# # Data Inspection:
# A critical initial step in any data analysis project is to thoroughly inspect the dataset
# to understand its structure, content, and any potential issues. The following aspects
# are f
# undamental in this process: Displaying the First Few Rows: One of the simplest
# and most effective ways to begin inspecting the dataset is by displaying the first few
# rows. This allows for a quick visual assessment of the data’s structure, format, and
# contents. Using the pandas library in Python, the head() f
# unction enables us to easily
# view the first five rows (by default) of the dataset.
#
# ---

# %%
#Displaying first 10 rows of dataset
df.head(10)
# Out:
#        DR_NO               Date Rptd                DATE OCC  TIME OCC  AREA  \
# 0  190326475  03/01/2020 12:00:00 AM  03/01/2020 12:00:00 AM      2130     7
# 1  200106753  02/09/2020 12:00:00 AM  02/08/2020 12:00:00 AM      1800     1
# 2  200320258  11/11/2020 12:00:00 AM  11/04/2020 12:00:00 AM      1700     3
# 3  200907217  05/10/2023 12:00:00 AM  03/10/2020 12:00:00 AM      2037     9
# 4  200412582  09/09/2020 12:00:00 AM  09/09/2020 12:00:00 AM       630     4
# 5  200209713  05/03/2020 12:00:00 AM  05/02/2020 12:00:00 AM      1800     2
# 6  200200759  07/07/2020 12:00:00 AM  07/07/2020 12:00:00 AM      1340     2
# 7  201308739  03/27/2020 12:00:00 AM  03/27/2020 12:00:00 AM      1210    13
# 8  201112065  07/31/2020 12:00:00 AM  07/30/2020 12:00:00 AM      2030    11
# 9  200121929  12/04/2020 12:00:00 AM  12/03/2020 12:00:00 AM      2300     1
#
#     AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 0    Wilshire          784         1     510
# ...

# %% [markdown]
# ---
# # Reviewing Column Names and Descriptions:
# "info" section is a valuable inclusion in a report because it provides a concise yet
# comprehensive summary of the dataset, offering insights into data types, missing
# values, memory usage, and data quality. It aids in efficient data exploration and
# supports informed decision-making during data analysis and preparation.
#
# ---

# %%
# Analyzing basic info of every column
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1003448 entries, 0 to 1003447
# Data columns (total 28 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   DR_NO           1003448 non-null  int64
#  1   Date Rptd       1003448 non-null  object
#  2   DATE OCC        1003448 non-null  object
#  3   TIME OCC        1003448 non-null  int64
#  4   AREA            1003448 non-null  int64
#  5   AREA NAME       1003448 non-null  object
#  6   Rpt Dist No     1003448 non-null  int64
#  7   Part 1-2        1003448 non-null  int64
#  8   Crm Cd          1003448 non-null  int64
#  9   Crm Cd Desc     1003448 non-null  object
#  10  Mocodes         851881 non-null   object
#  11  Vict Age        1003448 non-null  int64
#  12  Vict Sex        858856 non-null   object
#  13  Vict Descent    858844 non-null   object
#  14  Premis Cd       1003432 non-null  float64
#  15  Premis Desc     1002860 non-null  object
# ...

# %% [markdown]
# ---
# # Checking Data Types:
# Understanding the data types of each column is crucial. Data types determine how
# the data is stored and can affect subsequent data manipulation and analysis. Pandas
# offers a way to check the data types of each column in the dataset:
#
# ---

# %%
# Checking the data types
df.dtypes
# Out:
# DR_NO               int64
# Date Rptd          object
# DATE OCC           object
# TIME OCC            int64
# AREA                int64
# AREA NAME          object
# Rpt Dist No         int64
# Part 1-2            int64
# Crm Cd              int64
# Crm Cd Desc        object
# Mocodes            object
# Vict Age            int64
# Vict Sex           object
# Vict Descent       object
# Premis Cd         float64
# Premis Desc        object
# Weapon Used Cd    float64
# Weapon Desc        object
# Status             object
# Status Desc        object
# Crm Cd 1          float64
# Crm Cd 2          float64
# Crm Cd 3          float64
# Crm Cd 4          float64
# LOCATION           object
# Cross Street       object
# LAT               float64
# LON               float64
# dtype: object

# %% [markdown]
# ---
# # Data Cleaning
# In the phase of identifying and handling null values, missing data within the dataset was systematically detected and quantified. The code snippet crime_data.isnull().sum(), executed on the DataFrame crime_data, checks for null (or missing) values across all columns. The function isnull() identifies cells in the dataset that do not have valid values, marking them as 'True', and 'False' otherwise. The subsequent sum() function then tallies these 'True' values, effectively counting the number of null entries for each column. By executing this code, valuable insights into the extent and distribution of missing data within the dataset were gained. These findings will guide informed decisions on how to address these gaps during the data cleaning and preparation phase.
#
# ---

# %%
# Checking for null values
df.isnull().sum()
# Out:
# DR_NO                   0
# Date Rptd               0
# DATE OCC                0
# TIME OCC                0
# AREA                    0
# AREA NAME               0
# Rpt Dist No             0
# Part 1-2                0
# Crm Cd                  0
# Crm Cd Desc             0
# Mocodes            151567
# Vict Age                0
# Vict Sex           144592
# Vict Descent       144604
# Premis Cd              16
# Premis Desc           588
# Weapon Used Cd     676308
# Weapon Desc        676308
# Status                  1
# Status Desc             0
# Crm Cd 1               11
# Crm Cd 2           934330
# Crm Cd 3          1001133
# Crm Cd 4          1003384
# LOCATION                0
# Cross Street       849335
# LAT                     0
# LON                     0
# dtype: int64

# %% [markdown]
# ---
# Identifying columns with object data types that have missing values. Filling missing values in
# object-type columns using the mode (most frequent value). This ensures that categorical data
# remains consistent and meaningful.
#
# ---

# %%
# Handeling missing value with mode method
df['Mocodes'] = df['Mocodes'].fillna(df['Mocodes'].mode().iloc[0])
df['Vict Sex'] = df['Vict Sex'].fillna(df['Vict Sex'].mode().iloc[0])
df['Vict Descent'] = df['Vict Descent'].fillna(df['Vict Descent'].mode().iloc[0])
df['Weapon Desc'] = df['Weapon Desc'].fillna(df['Weapon Desc'].mode().iloc[0])
df['Status']=df['Status'].fillna(df['Status'].mode().iloc[0])
df['Cross Street']=df['Cross Street'].fillna(df['Cross Street'].mode().iloc[0])
df['Premis Desc'] = df['Premis Desc'].fillna(df['Premis Desc'].mode().iloc[0])

# %% [markdown]
# ---
# Identifying columns with numerical data types that have missing values. Filling missing values in
# numerical columns using the median (middle value). This helps maintain central tendency
# without being affected by outliers.
#
# ---

# %%
# Handeling missing value with median method
df['Premis Cd']=df['Premis Cd'].fillna(df['Premis Cd'].median())
df['Weapon Used Cd']=df['Weapon Used Cd'].fillna(df['Weapon Used Cd'].median())
df['Crm Cd 1']=df['Crm Cd 1'].fillna(df['Crm Cd 1'].median())

# %%
# Checking for null values
df.isnull().sum()
# Out:
# DR_NO                   0
# Date Rptd               0
# DATE OCC                0
# TIME OCC                0
# AREA                    0
# AREA NAME               0
# Rpt Dist No             0
# Part 1-2                0
# Crm Cd                  0
# Crm Cd Desc             0
# Mocodes                 0
# Vict Age                0
# Vict Sex                0
# Vict Descent            0
# Premis Cd               0
# Premis Desc             0
# Weapon Used Cd          0
# Weapon Desc             0
# Status                  0
# Status Desc             0
# Crm Cd 1                0
# Crm Cd 2           934330
# Crm Cd 3          1001133
# Crm Cd 4          1003384
# LOCATION                0
# Cross Street            0
# LAT                     0
# LON                     0
# dtype: int64

# %%
# Dropping columns with high percentage of null values
df.drop(columns=['Crm Cd 1','Crm Cd 2','Crm Cd 3','Crm Cd 4'],inplace=True)

# %% [markdown]
# ---
# # Duplicate Row Removal:
# In the data analysis process, it is vital to ensure that the dataset contains unique and non-repetitive information. Duplicate rows in a dataset can skew analysis results and potentially lead to inaccurate insights. To address this concern, the following data cleaning step was applied: The code df.drop_duplicates() was executed to eliminate duplicate rows from the dataset. Duplicate rows are those that have identical values across all fields. The resulting dataset contains only unique records, ensuring that each row represents distinct information, which enhances data accuracy and analytical validity. The head() function was used to display the first few rows of the cleaned dataset, offering a glimpse of the data's structure and content after removing duplicates.
#
# ---

# %%
# dropping duplicate rows
df.drop_duplicates().head(10)
# Out:
#        DR_NO               Date Rptd                DATE OCC  TIME OCC  AREA  \
# 0  190326475  03/01/2020 12:00:00 AM  03/01/2020 12:00:00 AM      2130     7
# 1  200106753  02/09/2020 12:00:00 AM  02/08/2020 12:00:00 AM      1800     1
# 2  200320258  11/11/2020 12:00:00 AM  11/04/2020 12:00:00 AM      1700     3
# 3  200907217  05/10/2023 12:00:00 AM  03/10/2020 12:00:00 AM      2037     9
# 4  200412582  09/09/2020 12:00:00 AM  09/09/2020 12:00:00 AM       630     4
# 5  200209713  05/03/2020 12:00:00 AM  05/02/2020 12:00:00 AM      1800     2
# 6  200200759  07/07/2020 12:00:00 AM  07/07/2020 12:00:00 AM      1340     2
# 7  201308739  03/27/2020 12:00:00 AM  03/27/2020 12:00:00 AM      1210    13
# 8  201112065  07/31/2020 12:00:00 AM  07/30/2020 12:00:00 AM      2030    11
# 9  200121929  12/04/2020 12:00:00 AM  12/03/2020 12:00:00 AM      2300     1
#
#     AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 0    Wilshire          784         1     510
# ...

# %% [markdown]
# ---
# # Data Type Conversion for Date and Time Fields:
# ## Converting Date Fields:
# The "Date Rptd" and "DATE OCC" fields in the dataset represent dates related to reported incidents and occurrence dates, respectively. To ensure data accuracy and enable chronological analysis, pd.to_datetime() was used to convert these fields from object data types to date data types. This conversion guarantees that dates are correctly recognized and processed, facilitating meaningful temporal analysis.
#
# ## Converting Time Fields:
# The "TIME OCC" field in the dataset represents the time of crime incidents. To standardize the time format and support precise time-related analysis, a process was performed to convert the time values. The "TIME OCC" field was transformed into a consistent time format ("HH:MM") by padding and reformatting the values. This transformation ensures uniform time values suitable for time-based analyses.
#
# ---

# %%
# converting object data type to date & time datatypes
from datetime import datetime as datetime

df['Date Rptd'] = pd.to_datetime(df['Date Rptd'])
df['DATE OCC'] = pd.to_datetime(df['DATE OCC'])

time_occ_list = df['TIME OCC'].apply(lambda x: str(x).zfill(4))
time_list = []

# convert 'TimeInt' column to time format
for time_item in time_occ_list:
     time_list.append( (datetime.strptime(str(time_item),"%H%M").time()).strftime("%H:%M"))

df['TIME OCC'] = time_list

df[['Date Rptd', 'DATE OCC' , 'TIME OCC']]
# Out:
# /var/folders/xr/g9v0_z654b5265b6cltzyq1m0000gn/T/ipykernel_11379/3023411536.py:4: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Date Rptd'] = pd.to_datetime(df['Date Rptd'])
# /var/folders/xr/g9v0_z654b5265b6cltzyq1m0000gn/T/ipykernel_11379/3023411536.py:5: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['DATE OCC'] = pd.to_datetime(df['DATE OCC'])
#          Date Rptd   DATE OCC TIME OCC
# 0       2020-03-01 2020-03-01    21:30
# 1       2020-02-09 2020-02-08    18:00
# 2       2020-11-11 2020-11-04    17:00
# 3       2023-05-10 2020-03-10    20:37
# 4       2020-09-09 2020-09-09    06:30
# ...            ...        ...      ...
# 1003443 2024-07-24 2024-07-23    14:00
# ...

# %%
df.head()
# Out:
#        DR_NO  Date Rptd   DATE OCC TIME OCC  AREA   AREA NAME  Rpt Dist No  \
# 0  190326475 2020-03-01 2020-03-01    21:30     7    Wilshire          784
# 1  200106753 2020-02-09 2020-02-08    18:00     1     Central          182
# 2  200320258 2020-11-11 2020-11-04    17:00     3   Southwest          356
# 3  200907217 2023-05-10 2020-03-10    20:37     9    Van Nuys          964
# 4  200412582 2020-09-09 2020-09-09    06:30     4  Hollenbeck          413
#
#    Part 1-2  Crm Cd                               Crm Cd Desc  ... Premis Cd  \
# 0         1     510                          VEHICLE - STOLEN  ...     101.0
# 1         1     330                     BURGLARY FROM VEHICLE  ...     128.0
# 2         1     480                             BIKE - STOLEN  ...     502.0
# 3         1     343  SHOPLIFTING-GRAND THEFT ($950.01 & OVER)  ...     405.0
# 4         1     510                          VEHICLE - STOLEN  ...     101.0
#
# ...

# %% [markdown]
# ---
# # Exploratory Data Analysis (EDA):
# ## Yearly Crime Analysis:
# In this section, the focus was on analyzing the dataset's temporal dimension by grouping the data based on the reporting year. This approach allowed insights into the trends and variations in crime incidents over time. The key steps and results are as follows:
#
# ## Data Grouping:
# The groupby() function was employed to group the data based on the "Date Rptd" field, which represents the date when crimes were reported. By using crime_data['Date Rptd'].dt.year, the reporting year was extracted from each date, enabling the organization of the data chronologically by year. The count() function was then applied to calculate the number of crimes reported in each year.
#
# ## Time Series Plot:
# To visualize the temporal trend, a time series plot was created to display the total number of crimes reported from 2020 to the present. The plot presents a clear overview of how crime incidents have evolved over the years. The x-axis represents the years, the y-axis shows the total number of crimes reported, and each point on the line plot represents a specific year's crime count.
#
# ---

# %%
# Grouping the data by year and count no of crimes 
yearly_analysis = df['Date Rptd'].groupby(df['Date Rptd'].dt.year).count()

# creating the time series plot
plt.figure(figsize =(12,6))
yearly_analysis.plot(kind = 'line', marker ='o',color ='green')
plt.title('Crime Analysis from 2020 to Present')
plt.xlabel('Year')
plt.ylabel('Total Crimes')
plt.savefig("Crime Analysis from 2020 to Present.png", format = "png", dpi = 300) 
plt.show()

# %% [markdown]
# ---
# # Analysis:
# The resultant time series plot reveals how crime rates have evolved over time, showing the general crime patterns from 2020 to the present. The plot highlights a significant increase in crime rates between 2021 and 2022.
#
# ## Monthly Crime Analysis:
# In this section, the focus was on understanding the dataset's temporal patterns at a monthly level by extracting and analyzing the reporting months. The following steps and results were obtained:
#
# ## Month Extraction:
# The month was extracted from the "Date Rptd" column using the dt.month property. This allowed for the isolation of the reporting months, providing insights into monthly variations in crime reports.
#
# ## Monthly Crime Counts:
# After extracting the reporting months, the number of crimes reported for each month was counted. The resulting counts were sorted in chronological order for clear representation.
#
# ## Visualization:
# To visualize the monthly crime counts, a bar plot was created. Each bar in the plot represents a month, and its height corresponds to the total number of crimes reported in that month. The x-axis displays the months (January to December), while the y-axis indicates the total crime counts.
#
# ---

# %%
#extracting month from "Date Rptd"
df['Month'] = df['Date Rptd'].dt.month

#counting no. of crimes 
Counts_Monthly = df['Month'].value_counts().sort_index()

#plotting the graph
plt.figure(figsize=(10, 6))
Counts_Monthly.plot(kind='bar', color='blue')
plt.title('Monthly Crime Counts')
plt.xlabel('Months')
plt.ylabel('Total Crimes')
plt.xticks(range(0, 12), ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.savefig("Monthly Crime Counts.png", format = "png", dpi = 300)
plt.show()

# %% [markdown]
# ---
# # Analysis:
# The bar plot suggests that the months of January and March record the highest crime rates, while November and December show significantly lower rates, indicating a drop in crime during the holiday season.
#
# ## Top Crime Types Analysis:
# In this section, an analysis was conducted to identify and visually represent the most frequently occurring crime types in the dataset. The essential details are as follows:
#
# ## Analysis of Crime Types:
# The value_counts() function was used to count the occurrences of various crime types in the dataset. The focus was placed on the top 10 most prevalent crime types, which were sorted in ascending order for easier presentation.
#
# ## Visual Presentation:
# To clearly visualize the leading crime types, a horizontal bar graph was generated. Each horizontal bar within the graph represents a distinct crime type, with its length indicating the frequency of occurrences. The x-axis displays the count of occurrences, while the y-axis labels the individual crime types.
#
# ---

# %%
# initalizing size of graph
fig,axes=plt.subplots(figsize=(7,4))
# counting total types of crimes and plotting 
df['Crm Cd Desc'].value_counts().iloc[:10].sort_values().plot(kind='barh',title='Top Crime Rates',color='green')
plt.xlabel('Number Of Occurences')
plt.ylabel('Crime Types')
plt.show()

# %% [markdown]
# ---
# # Analysis:
# The crime type with the largest number of reported incidents is Stolen Vehicle, with more than 100,000 occurrences.
#
# ## Crime Rates Across Regions Analysis:
# In this section, the focus was on examining the distribution of crime incidents across different regions or areas within the dataset. The key elements of this analysis are summarized as follows:
#
# ## Analysis by Areas:
# The dataset was analyzed by grouping it based on the "AREA NAME" field, which delineates the distinct regions or areas where crimes are reported. The count() function was employed to calculate the number of recorded crime incidents in each area.
#
# ## Visual Presentation:
# To vividly depict the distribution of crime rates across regions, a bar plot was chosen. Each bar in the plot corresponds to a unique region or area, with its height representing the total count of crimes reported within that specific area. The x-axis is labeled with the names of the regions or areas, while the y-axis quantifies the total number of reported crimes.
#
# ---

# %%
area_crimes = df['AREA NAME'].groupby(df['AREA NAME']).count()
plt.figure(figsize =(10,6))
sns.barplot(x=area_crimes.index, y= area_crimes.values, palette =
'viridis')
plt.title('Crime Rates across Regions')
plt.xlabel('Region/Area Names')
plt.ylabel('Total Crimes By Area')
plt.xticks(rotation=90)
plt.savefig("Crime Rates across Regions.png", format = "png", dpi = 300) 
plt.show()
# Out:
# /var/folders/xr/g9v0_z654b5265b6cltzyq1m0000gn/T/ipykernel_11379/3211776214.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=area_crimes.index, y= area_crimes.values, palette =

# %% [markdown]
# ---
# # Analysis:
# The central region has the highest number of total crimes, as shown in the bar plot.
#
# ## Correlation Between Economic Factors and Crime Rate:
# This section explores the relationship between economic factors and crime rates. Key components include:
#
# ## Data Aggregation:
# The crime data was grouped by "Date Rptd" to analyze daily crime distribution.
#
# ## Economic Dataset Integration:
# The Los Angeles Economic Dataset, containing indicators such as GDP, unemployment, and cost of living, was integrated. A "Crime count" column was added to represent daily crime incidents.
#
# ## Correlation Analysis:
# Correlation coefficients between "Crime count" and economic indicators were calculated. The correlation matrix reveals the strength and direction of relationships between crime rates and economic factors.
#
# ---

# %%
df1=pd.read_csv('Crime_Data_from_2020_to_Present.csv')
df2=pd.read_csv('la_economicdata.csv')
df1['Date Rptd'] = pd.to_datetime(df1['Date Rptd'])

crm_dt = df1.copy()
crm_dt = crm_dt.reset_index()
crm_dt['Month'] = crm_dt['Date Rptd'].dt.month
crm_dt['Year'] = crm_dt['Date Rptd'].dt.year
crm_dt = crm_dt.groupby(['Year', 'Month']).count()

LA_Economy_data = pd.read_csv('la_economicdata.csv')
LA_Economy_data['Crime Count'] = crm_dt['DR_NO'].reset_index()['DR_NO']


correlation = LA_Economy_data[['Crime Count', 'GDP (in billions)', 'Per Capita Income','Unemployment Rate (%)','Annual Income','Poverty Rate (%)','Education Level (years)','Population','Urbanization Rate (%)']].corr()
plt.figure(figsize=(10, 6))
sns.heatmap(data = correlation,annot=True) 
plt.title('Correlation between Economic Factors and Crime Rate')
plt.savefig("Correlation between Economic Factors and Crime Rate.png", format = "png", dpi = 300) 
plt.show()
# Out:
# /var/folders/xr/g9v0_z654b5265b6cltzyq1m0000gn/T/ipykernel_11379/337890940.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df1['Date Rptd'] = pd.to_datetime(df1['Date Rptd'])

# %% [markdown]
# ---
# ## Day of the Week Crime Analysis:
# This section examines the correlation between the day of the week and the frequency of specific crime types, aiming to identify day-of-week patterns.
#
# ## Day of the Week Extraction:
# The day of the week was extracted from the "Date Rptd" column to categorize each reported crime by day.
#
# ## Crime Type and Day-of-Week Frequencies:
# The data was grouped by both "Day_of_Week" and "Crm Cd Desc" to count occurrences of each crime type across all days of the week.
#
# ## Top Crime Types:
# The analysis focused on the top 5 most frequently occurring crime types, identified based on their frequency in the dataset.
#
# ---

# %%
df[ 'Day_of_Week'] = pd.to_datetime(df['Date Rptd']) .dt.day_name()
# Group the data by 'Day_of_Week' and 'Crm Cd Descand count the occurrences
crime_type_day_of_week = df.groupby(['Day_of_Week','Crm Cd Desc']).size().unstack(fill_value=0)
# Get the top N crime types
top_N = 5
top_crime_types = df['Crm Cd Desc'].value_counts().head(top_N).index
crime_type_day_of_week = crime_type_day_of_week[top_crime_types]

crime_type_day_of_week.plot(kind='bar')
plt.title('The top five types of crimes by frequency per day of the week.') 
plt.xlabel ('Day of Week')
plt.ylabel ('Crime Frequency')
plt.rcParams["figure.figsize"] = (25,15)
plt.legend(title='Crime Type',loc='upper right',fontsize=8.5)

plt.xticks(range(0,7), ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'], rotation=90)
plt. show()

# %% [markdown]
# ---
# # Analysis:
# Tuesdays record the highest number of crimes, with Stolen Vehicle crimes being the most frequent, as seen in previous trends.
#
# ## Temporal Analysis:
# Date Conversion:
# The "Date Rptd" column was converted to a datetime format for accurate temporal analysis.
#
# ## Monthly Crime Counts:
# The number of crimes reported each month over several years was counted, revealing temporal patterns and trends.
#
# ## Visualization:
# A line plot was created to visualize crime rate variations over time, with the x-axis representing years and months, and the y-axis showing the number of crimes.
#
# ## Notable Events:
# Significant events, such as the "3rd Wave" of the COVID-19 pandemic, were identified and marked on the plot, providing context for crime rate fluctuations.
#
# ---

# %%
df['Date Rptd']= pd.to_datetime(df['Date Rptd'])
month_count = df.groupby([df['Date Rptd'].dt.year, df['Date Rptd'].dt.month]).size()

plt.figure(figsize =(12,8))
month_count.plot(kind='line')

# Construct xtick_labels for the x-axis
xtick_labels = [f'{year}-{month:02}' for year, month in month_count.index]

# Print xtick_labels for debugging purposes
#print(xtick_labels)

# Plot x-ticks at every second label for better readability
plt.xticks(range(0, len(xtick_labels), 2), xtick_labels[::2], rotation = 45)
strt_3rd_wave_date = '2022-07'  # Example start date of the 3rd wave
strt_label = 'Start of 3rd Wave'
last_3rd_wave_date = '2022-11'  # Example end date of the 3rd wave
last_label = 'End of 3rd Wave'

# Annotate start of 3rd wave
if strt_3rd_wave_date in xtick_labels:
    plt.annotate(strt_label, xy=(xtick_labels.index(strt_3rd_wave_date), 19770), xytext=(80, 40),
                 textcoords='offset points', arrowprops=dict(arrowstyle='-|>', lw=0.9, color='brown'), fontsize=10)
else:
    print(f"'{strt_3rd_wave_date}' not found in xtick_labels")

# Annotate end of 3rd wave
if last_3rd_wave_date in xtick_labels:
    plt.annotate(last_label, xy=(xtick_labels.index(last_3rd_wave_date), 18800), xytext=(20, -80),
                 textcoords='offset points', arrowprops=dict(arrowstyle='-|>', lw=0.9, color='green'), fontsize=10)
else:
    print(f"'{last_3rd_wave_date}' not found in xtick_labels")

plt.xlabel('Years & Months')
plt.ylabel('Number of Crimes')
plt.title('Crime rates before and after the 3rd COVID-19 wave')

plt.show()

# %% [markdown]
# ---
# # Analysis:
# The graph shows fluctuations in crime rates during the 3rd wave of COVID-19, but the highest and lowest crime rates in this period do not correspond to the highest or lowest recorded overall.
#
# ## Distribution Based on Age, Gender, and Crime Type:
# Age Distribution Histogram:
# The histogram displays the distribution of victim ages, with the x-axis representing age, the y-axis representing frequency, and the data shown in sky-blue. It reveals the age groups most affected by crime.
#
# ## Gender Distribution Bar Chart:
# A bar chart shows the distribution of victim genders, with the x-axis representing gender and the y-axis representing the count. Teal bars represent male and female victims, offering a visual comparison of gender distribution.
#
# ## Top Crime Types Horizontal Bar Chart:
# A horizontal bar chart visualizes the top 5 most frequent crime types, with bar lengths indicating the number of occurrences. Distinct colors for each bar provide a clear comparison of the most common crimes.
#
# ---

# %%
crime_counts=df['Crm Cd Desc'].value_counts()
top_crime_counts=crime_counts[:5]

# %%
# Histogram for age distribution
plt.figure(figsize = (8,6))
plt.hist(df['Vict Age'], bins=30 ,color= 'skyblue')
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()
# Bar chart for gender distribution
plt.figure(figsize=(6,6))
df['Vict Sex'].value_counts().plot(kind ='bar', color ='teal')
plt.title('Gender Distribution')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()
#Horizontal Bar chart for top 5 frequent crime types
plt.figure(figsize=(10, 6))
top_crime_counts.sort_values().plot(kind='barh', color=['skyblue', 'orange', 'green', 'red', 'gold'])
plt.title('Crime Type Distribution')
plt.xlabel('Number of Occurrences')
plt.ylabel('Crime Types')
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# "The histogram representing age distribution was created using Matplotlib, a Python library for creating static, animated, and interactive visualizations (Hunter, 2007)."
# "Gender distribution and crime type analysis charts were generated using Pandas and Matplotlib libraries (Hunter, 2007; pandas development team, 2020)."

# %% [markdown]
# ---
# # Analysis:
# The visualizations of age, gender, and crime types clearly illustrate how demographics influence crime rates and highlight recurring crime patterns.
#
# ## Advanced Analysis:
# The dataset was organized chronologically by incident occurrence, allowing for a clear timeline of events. It was then resampled to a monthly frequency, summarizing the number of crimes reported each month. This transformation provides a broader view of trends and patterns in criminal activity, laying the foundation for deeper temporal analysis in the next phases.
#
# ---

# %%
df.set_index('DATE OCC',inplace=True)
df.sort_index(inplace=True)
crime=df.resample('M').size()
# Out:
# /var/folders/xr/g9v0_z654b5265b6cltzyq1m0000gn/T/ipykernel_11379/2714382276.py:3: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   crime=df.resample('M').size()

# %% [markdown]
# ---
# # Time Series Analysis:
# The ARIMA(1,1,1) time series model was applied to the resampled crime data to capture underlying patterns. The model’s training and fitting results were summarized, offering insights into its performance and the significance of its parameters. This analysis is key for understanding and potentially predicting future crime trends, aiding law enforcement and policy-making efforts.
#
# ---

# %%
import pandas as pd
from statsmodels.tsa.arima.model import ARIMA

# Fit an ARIMA(1,1,1) model to the 'Crime Count' time series
model = ARIMA(crime, order=(1, 1, 1))
results = model.fit()

# Print the model summary
print(results.summary())
# Out:
#                                SARIMAX Results
# ...
# Dep. Variable:                      y   No. Observations:                   60
# Model:                 ARIMA(1, 1, 1)   Log Likelihood                -499.179
# Date:                Sat, 11 Jan 2025   AIC                           1004.358
# Time:                        14:26:07   BIC                           1010.591
# Sample:                    01-31-2020   HQIC                          1006.791
#                          - 12-31-2024
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.9266      0.243      3.817      0.000       0.451       1.402
# ma.L1         -0.8968      0.269     -3.334      0.001      -1.424      -0.370
# sigma2      1.289e+06   2.14e+05      6.033      0.000     8.7e+05    1.71e+06
# ...

# %% [markdown]
# ---
# # Crime Count Forecasting for the Next 12 Months:
# The ARIMA model was used to forecast crime counts for the next 12 months, with forecasted values and their confidence intervals displayed. This information is crucial for proactive planning and resource allocation in law enforcement and public safety efforts, offering an estimate of expected crime levels and associated uncertainties.
#
# ---

# %%
# forecast the next 12 months 
forecast_steps=12
forecast=results.get_forecast(steps=forecast_steps)
# get forecasted values and their intervals
forecast_values=forecast.predicted_mean
confidence_intervals=forecast.conf_int()
# print the forecasted values and their intervals
print('Forecasted Crime Counts:')
print(forecast_values)
print('\nConfidence Intervals:')
print(confidence_intervals)
# Out:
# Forecasted Crime Counts:
# 2025-01-31    3150.000818
# 2025-02-28    2892.411759
# 2025-03-31    2653.734355
# 2025-04-30    2432.580152
# 2025-05-31    2227.662632
# 2025-06-30    2037.789731
# 2025-07-31    1861.856905
# 2025-08-31    1698.840703
# 2025-09-30    1547.792813
# 2025-10-31    1407.834545
# 2025-11-30    1278.151724
# 2025-12-31    1157.989946
# Freq: ME, Name: predicted_mean, dtype: float64
#
# Confidence Intervals:
#                 lower y      upper y
# 2025-01-31   925.111280  5374.890355
# 2025-02-28  -301.202895  6086.026413
# 2025-03-31 -1312.750079  6620.218790
# 2025-04-30 -2208.261620  7073.421924
# 2025-05-31 -3025.747110  7481.072374
# 2025-06-30 -3784.737380  7860.316843
# 2025-07-31 -4496.945977  8220.659787
# 2025-08-31 -5170.133207  8567.814614
# 2025-09-30 -5809.814845  8905.400470
# 2025-10-31 -6420.122486  9235.791576
# 2025-11-30 -7004.278837  9560.582285
# 2025-12-31 -7564.879339  9880.859232

# %% [markdown]
# ---
# # Crime Data Visualization and Forecasting:
# The provided code generates a visual representation of crime data using a line plot. It includes:
# Actual Data: Displayed in blue dots, representing observed crime counts over time. Forecasted
# Values: Shown in red, indicating predicted crime counts based on the ARIMA model. Confidence
# Intervals: Depicted as a shaded area around the forecasted values, representing the range within
# which future values are likely to fall.
#
# ---

# %%
# plot the actual observed data
plt.figure(figsize=(10,6))
plt.plot(crime.index,crime.values,label='Actual',marker='o')
#plot the forecasted values
plt.plot(forecast_values.index,forecast_values.values,color='red',label='Forecast',marker='o')
# customize the plot
plt.fill_between(confidence_intervals.index,confidence_intervals.iloc[:,0],confidence_intervals.iloc[:,1],color='pink',alpha=0.3,label='confidence Intervals')
plt.title('Crime Forcasting')
plt.xlabel('Date')
plt.ylabel('Crime Counts')
plt.legend()
plt.grid(True)
plt.savefig("Crime Forcasting.png", format = "png", dpi = 300)
plt.show()

# %% [markdown]
# ---
# # Analysis:
# The ARIMA model forecasts that crime rates will fall within the confidence levels and highlights the predicted trends for the upcoming year.
#
# ## Victim Demographics and Crime Type Frequencies:
# Summary Statistics for Age and Gender:
# Descriptive statistics (mean, standard deviation, min, max, and quartiles) were calculated for 'Vict Age', offering insights into the distribution of victim ages. For 'Vict Sex', we analyzed the count of unique categories (e.g., male, female) and the most frequent category.
#
# ## Count of Crime Types:
# The frequency of each crime type ('Crm Cd Desc') was calculated, providing a breakdown of crime occurrences in the dataset. The top 5 most frequent crime types were identified based on their counts, highlighting those of particular interest.
#
# ---

# %%
# calculate the summary stats for age and gender
print(df[['Vict Age']].describe())
print('\n')
print(df[['Vict Sex']].describe())
print('\n')
print(crime_counts)
# Out:
#            Vict Age
# count  1.003448e+06
# mean   2.891332e+01
# std    2.199538e+01
# min   -4.000000e+00
# 25%    0.000000e+00
# 50%    3.000000e+01
# 75%    4.400000e+01
# max    1.200000e+02
#
#
#        Vict Sex
# count   1003448
# unique        5
# top           M
# freq     547786
#
#
# Crm Cd Desc
# VEHICLE - STOLEN                                           115186
# BATTERY - SIMPLE ASSAULT                                    74816
# BURGLARY FROM VEHICLE                                       63259
# THEFT OF IDENTITY                                           62408
# VANDALISM - FELONY ($400 & OVER, ALL CHURCH VANDALISMS)     60956
#                                                             ...
# FIREARMS EMERGENCY PROTECTIVE ORDER (FIREARMS EPO)              5
# FIREARMS RESTRAINING ORDER (FIREARMS RO)                        4
# DISHONEST EMPLOYEE ATTEMPTED THEFT                              4
# TRAIN WRECKING                                                  1
# ...

# %% [markdown]
# ---
# # Analysis:
# The initial analyses reveal that the average age of individuals involved in criminal activities is approximately 30 years. Additionally, males account for the majority of the recorded crimes, with a frequency of 535,214.

# %% [markdown]
# ---
# # Conclusion
# The exploratory data analysis (EDA) of crime data in Los Angeles from 2020 to the present has provided significant insights into the city's criminal activity. Clear temporal trends were identified, with certain crime types exhibiting noticeable increases during specific periods. The application of the ARIMA time series model facilitated the forecasting of future crime patterns, serving as a valuable resource for proactive law enforcement planning. The forecasts, along with their confidence intervals, offer a level of certainty that supports informed decision-making. Overall, this EDA provides a comprehensive understanding of crime dynamics in Los Angeles. The insights generated can inform law enforcement strategies, enhance resource allocation, and guide policy-making efforts aimed at improving public safety and reducing crime in the city.

# %% [markdown]
# ---
# ## References

# %% [markdown]
# 1.  R. K. Pearson,Exploratory Data Analysis Using R, 1st Editio. CRC Press/Taylor & Francis Group, 2018.
#
# 2.  I. Setiawan, “Pengembangan Prototipe Aplikasi Manajemen Risiko Berbasis ISO 31000,” Matrix J. Manaj. Teknol. dan Inform., vol. 10, no. 1, pp. 26–33, 2020, doi: 10.31940/matrix.v10i1.1817.
#
# 3.  S. S. P. & Keamanan, “Statistik Kriminal 2018,” 2018
#
# 4.  Hunter, J. D. (2007). Matplotlib: A 2D Graphics Environment. Computing in Science & Engineering, 9(3), 90–95. https://doi.org/10.1109/MCSE.2007.55
#
# 5.  City of Los Angeles (2025). Crime Data from 2020 to Present. Available at: https://catalog.data.gov/dataset/crime-data-from-2020-to-present .
#
# 6.  Box, G.E.P. and Jenkins, G.M. (1970). Time Series Analysis: Forecasting and Control. San Francisco: Holden-Day. Available at:https://www.researchgate.net/publication/285902264_ARIMA_The_Models_of_Box_and_Jenkins
#
# 7.  OpenAI (2025). ChatGPT: Exploring Python Libraries and Functions for Data Analysis and Visualization. Available at: https://chat.openai.com
#
# 8.  OpenAI (2025). ChatGPT: Assisting with Grammar Correction and Text Generation. Available at: https://chat.openai.com
#
# 9.  The pandas development team (2020). pandas-dev/pandas: Pandas (Version 1.0.3) [Software]. Zenodo. Available at: https://doi.org/10.5281/zenodo.3509134 .
#
# 10.  Waskom, M. (2021). Seaborn: Statistical Data Visualization. Available at: https://seaborn.pydata.org/
#
# 11.  McKinney, W. (2010). Data Structures for Statistical Computing in Python. In Proceedings of the 9th Python in Science Conference, 51-56. https://doi.org/10.25080/majora-92bf1922-00a.
#
# 12.  Tufte, E. R. (2001). The Visual Display of Quantitative Information. Graphics Press.
#
# 13.  VanderPlas, J. (2016). Python Data Science Handbook: Essential Tools for Working with Data. O'Reilly Media.
#
# 14.  Raphael, S., & Winter-Ebmer, R. (2001). "Identifying the Effect of Unemployment on Crime." The Journal of Law and Economics, 44(1), 259-283. https://doi.org/10.1086/320268.
#
# 15.  McKinney, W., 2011. pandas: a foundational Python library for data analysis and statistics. Python for high performance and scientific computing, 14(9), pp.1-9.
#
# 16.  Han, S. and Kwak, I.Y., 2023. Mastering data visualization with Python: practical tips for researchers. Journal of Minimally Invasive Surgery, 26(4), p.167.
#
# 17.  Chatfield, C., 1986. Exploratory data analysis. European journal of operational research, 23(1), pp.5-13.
# ---
